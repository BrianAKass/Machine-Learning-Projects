# %% [markdown]
# # Intro to Logistic Regression
#
# * We want to learn about Logistic Regression as a method for Classification.
# * Some examples of classification problems:
#     * Spam Vs "Ham" emails.
#     * Loan Default(Yes/No)
#     * Disease Diagnosis
# * Above were all example of Binary Classification
#
# * So far we've only seen regression problems where we try to predict a continuous value.
#
# * Although the name may be confusing at first, logistic regression allows us to solve classification problems, where we are trying to predict discrete categories.
#
# * The convention for binary classification is to have two classes 0 and 1.
#
# * We cant use a normal linear regression model on Binary groups as it won't lead to a good fit.
#
# * Instead we can transform our linear regression to a logistic regression curve.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * The sigmoid (AKA Logistic) Function takes in any value and outputs it to be between 0 and 1.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * This means we can take our Linear Regression Solution and place it into the Sigmoid Function.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * This results in a probability from 0 to 1 of belonging in the 1 class.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * This means we can set a cut off point at 0.5, anything below it results in class 0, and anything above is class 1.
#
# * We use the logistic function to output a value ranging from 0 to 1. Based off this probability we assign a class.
#
# ![image.png](attachment:image.png)
#
# * After you train a logistic regression model on some trainig data, you will evaluate your model's performance on some test data.
#
# * You can use a confusion matrix to evaluate classification models.

# %% [markdown]
# * We can use a confusion matrix to evaluate our model.
#
# * for example, imagine testing for disease.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### Accuracy:
#
# * Overall how often is it correct?
#
# * (TP+TN)/total =150/165=0.91
#
# #### Misclassification Rate (Error Rate):
#
# * Overall, how often is it wrong?
#
# * (FP+FN)/total = 15/165=0.09

# %% [markdown]
# ### In case you are still confused....
#
# ![image.png](attachment:image.png)
#
# * Lets go ahead and begin to explore an example of Logistic Regression using the famous Titanic data set to attempt to predict whether or not a pssenger survived based off of their features.
#
# * Then you'll have a portfollio project with some Advertising data trying to predict whether or not a customer clicked on an ad.
