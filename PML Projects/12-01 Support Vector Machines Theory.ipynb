# %% [markdown]
# Read chapter 9 ISLR book.
#
# Support vector machines (SVMs) are supervised learning lodels with associated learning algorithms that analyze data and recognize patterns, used for classification and regression analysis.
#
# Given a set of training examples, each marked for belonging to one of two categories, an SVM training algorithm builds a model that assigns new examples into one category or the other, making it a non-probabilistic binary linear classifier.
#
# An SVM model is a representation of the example as points in space, mapped so that the examples of the seperate categories are divided by a clear gap that is as wide as possible.
#
# New examples are then mapped into that same space and predicted to belong to a category based on which side of the gap they fall on.
#
# Let's show the basic intuition behind SVMs. Imagine the labeled training Data bellow:
#
# ![image.png](attachment:image.png)
#
# We can draw a separating "hyperplane" between the classes.
# But we have many options of hyperplanes that seperate perfectly...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We would like to choose a hyperplane that maximizes the margin between classes.
# ![image.png](attachment:image.png)

# %% [markdown]
# The vector points that the margin lines touch are known as support vectors.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# we can expand this idea to non-linearly seperable data though the "kernel trick".
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Check out youtube for nice 3d visualization video explaining this idea. refer to reading fo the math behind this.
# ![image.png](attachment:image.png)
#
# We'll start our example by using Support Vector Machines. to predict whether a tumor is malignant or benign. then your portfolio project will apply these same concepts to the famous iris flower data set.
#
# Then we'll learn how to tune our models with a GridSearch.
