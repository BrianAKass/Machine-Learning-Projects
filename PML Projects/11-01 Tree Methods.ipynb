# %% [markdown]
# TODO: Read chaper 8 of ISLR
#
# Let's start off with a thought experiment to give some motivation behind using a decision tree method.
#
# Imagine I play Tennis every Saturday and I always invite a friend to come with me. Sometimes friend shows up, sometimes not.
#
# For him it depends on a varietey of factors, such as:weather, temperature,humidity, wind,etc..
#
# I start keeping track of these features and whether or not he showed up to play with me.
# ![image.png](attachment:image.png)

# %% [markdown]
# I want to use this data to predict wheter or not he will show up and play. An intuitive way to do this is through a Decision Tree.
#
# ![image.png](attachment:image.png)
#
# In this tree we have:
#
# #### Nodes:
#     - Split for the value of a certain attribute
# #### Edges:
#      - Outcome of a split to next node
# #### Root:
#     - The node that performs the first split
# #### Leaves:
#     - Terminal nodes that predict the outcome

# %% [markdown]
# ### Intuition Behind Splits
#
# Imagainry Data with 3 features (X,Y, and Z) with two possible classes)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Splitting on Y gives us clear separation between classes
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We could have also tried splitting on other features first:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Entrophy and information Gain are the Mathematical Methods of choosing the best split. Refer to reading assignment.
#
# $$Entrophy:$$
# $$H(S)=-\sum_{i}p_{i}(S)log_{2}P_i(S)$$
#
# $$Information Gain:$$
# $$IG(S,A)=H(S)-\sum_{v\epsilon Values(A)}\frac{|S_v}{S}H(S_v)$$
#
#
# ### Random Forests
#
# To imporve performance, we can use many trees with a random sample of features chosen as the split.
# * A new random sample of features is chosen for $every\ single\ tree\ at\ every\ single\ split$.
#
# * For $classification$, m is typically chosen to be the square root of p.
#
# What's the point?
#
# * Suppose there is $one\ very\ strong\ feature$ in the data set. When using "bagged" trees, most of the tree will use that feature as the top split, resulting in an ensamble of similar trees that are $highly\ corrected$.
#
# * Averaging highly correlated quantities does not significantly reduce variance.
#
# * By randomly leaving out candidate features from each split, $Random\ Forests\ "decorrelates"\ the\ trees$,such that the averaging process can reduce the variance of the resulting model.
#
# We'll start by looking at a small example data set of Kyphosis (a medical spine condition) patients and try to predict whether or not a corrective spine surgery was successful.
#
# Then for your portfollio project we'll use loan data from Lending Club to predict default rates.
