# %% [markdown]
# # Natural Language Processing
#
#
# Imagine you work for google news and you want to group news articles by topic.
#
# Maybe you work for a legal firm and you need to sift through thousands of pages of legal documents to find relevant ones.
#
# This is where Natural language processing can help!
#
# We will want to:
#
# * Compile Documents
#
# * Featurize Them
#
# * Compare their features
#
# Simple Example:
#
# * You have two documents:
#     * "Blue House"
#     * "Red House"
# * Featurize based on word count:
#     * "Blue House" -> (red,blue,house) ->(0,1,1)
#     * "Red House" -> (red,blue,house) ->(1,0,1)
#
# * A document represented as a vector of a word counts is called a "Bag of Words"
#     * "Blue House" -> (red,blue,house) ->(0,1,1)
#     * "Red House" -> (red,blue,house) ->(1,0,1)
# * You can use cosine similarity on the vectors made to determine similarity:
#
# ![image.png](attachment:image.png)
#
# * We can improve on Bag of Words by adjusting word counts based on their frequency in corpus (the group of all the documents)
#
# * We can use TF-IDF (Term Frequency - Inverse Document Frequency)
#
# * Term Frequency - Importance of the term within that document
#     * TF(d,t) = Number of occurrences of term t in document d
# * Inverse Document Frequency - Importance of the term in the corpus
#     * IDF(t) = log(D/t) where
#         * D = total number of documents
#         * t = number of documents with the term

# %% [markdown]
# * Mathematically, TF-IDF is then expressed:
# ![image.png](attachment:image.png)
#
# Before we get started with Natural Language Processing and Python we'll need to download an additional library, go to your terminal or command line and use: *conda install nltk* or *pip install nltk*
#
# We'll start by building a spam filter with Python then your portfolio project will have you working with real data from yelp.
